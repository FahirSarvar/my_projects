# %%
# 1 comparing None
b = None
print (f'type of {b}=> {type(b)}')

value = False
print(f'{b} == {value} => {b==value}')

value = 0
print(f'{b} == {value} => {b==value}')

value = ''
print(f'{b} == {value} => {b==value}')

value = None
print(f'{b} == {value} => {b==value}')

# 2 checking data types
print(type(32))
print(type(3.141592))
print(type(True))
print(type('Narendra is evil!'))
print(type({1, 3, 2, 3, 4}))
print(type((4, 'five', 6.0, {'one'})))
print(type([1, '1.1', 1.2, (2,)]))
print(type({0: 'zero', 1: 'one', 2: 'two'}))

# 3 asking user 

#name = input('print name')
#lastname = input('print lastname')

#print(f'{name} {lastname}')

#name = input('print name')
#middlename = input('print middlename')
#lastname = input('print lastname')

#print(f'{name} {middlename} {lastname}')

#name = input('print name')
#middlename = input('print middlename')
#lastname = input('print lastname')

#print(f'{lastname},{name} {middlename}')

# Tuples

a=(28,1.8,'one','Jack',None)
print(a)

# 5 Lists

b=[30,4.6,'two','Bob',True]
print(b)

# 6 Sets

print({1,2.5,'John',None, 2.5,"three",10, 10, 'John',1,'six'})

# 7 Dictionaries

print({'name': 'Fahir', 'age': 22, 'course': 'coding'})

# 8 Boolean

print(bool(None))
print(bool(''))
print(bool([]))
print(bool(0))
print(bool(42))
print(bool('Python'))

# 9 integers 
Decimal= 42
Binary = 0b101010
Octal = 0o52
Hexadecimal = 0x2A

print(f'{Decimal},{Binary},{Octal}, {Hexadecimal}')
print(Decimal==Binary==Octal==Hexadecimal)

# 10 FLoats 
pi=3.1425
#r = float(input('please enetr the radius of a circle'))
#print(F'the area of the circle with radius {r:.2f} is {pi * r ** 2:.2f}')

# 11

#siblings=input('how many siblings do you have?')
#print(F'I also have {siblings} siblings')

# 12

#n1=int(input('enter the firts number'))
#n2=int(input('enter the second number'))

#print(f'{n1}-{n2}={n1+n2}')
#print(f'{n1}+{n2}={n1+n2}')

# 13

#a = float(input('enetr the number'))
#b=int(a)
#letter=chr(b)
#print(f'{a:.3f}')
#print(b)
#print(letter)

# 14

#a=float(input('enter the current'))
#ohms=float(input('enetr the resistance'))
#v=(a*ohms)
#print(f'if the current is {a} and the resistance is {ohms}, then the potential difference will be {v:.2f}V')

# 15

at=3.75
cht=2.25

a=int(input('enter the number of adults'))
ch=int(input('ennter the numebr of children'))
cost=float((at*a+cht*ch))
print(f'{a} adults and {ch} children will cost ${cost:.2f}')
# Out:
# type of None=> <class 'NoneType'>
# None == False => False
# None == 0 => False
# None ==  => False
# None == None => True
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# <class 'set'>
# <class 'tuple'>
# <class 'list'>
# <class 'dict'>
# (28, 1.8, 'one', 'Jack', None)
# [30, 4.6, 'two', 'Bob', True]
# {None, 1, 2.5, 'six', 'three', 10, 'John'}
# {'name': 'Fahir', 'age': 22, 'course': 'coding'}
# False
# False
# False
# False
# True
# True
# 42,42,42, 42
# True
# 6 adults and 12 children will cost $49.50
